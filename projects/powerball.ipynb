# %% [markdown]
# # Powerball Introduction
# Each dollar prize and their odds for the powerball is listed below.
#
# |-----|------|
# | Prize | Odds |
# |--------|-------|
# |Jackpot  |	1/292,201,338 |
#
# | $1 Million | 1/11,688,053.52 |
#
# | $50,000 | 1/913,129.18 |
#
# | $100 | 1/36,525.17 |
#
# $100	1 in 14,494.11 |
#
# $7	1 in 579.76 |
# |$7| 1/701.33 |
# |$4	| 1/91.98 |
# |$4 | 1/38.32 |
# The odds of each megaplier multiplier is listed below. These apply to each level except the
